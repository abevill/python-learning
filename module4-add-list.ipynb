# %%
print('hello')
# Out:
# hello

# %%
name = input('name?')
# Out:
# name? hi

# %%
book_ratings = [7, 9, 5, 6, 8]
book_ratings.append(4)
print(book_ratings)
# Out:
# [7, 9, 5, 6, 8, 4]

# %%
append(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 append(4)
#
# NameError: name 'append' is not defined

# %%
book_ratings = [7, 9, 5, 6,
