# %%
2+3
# Out:
# 5

# %%
3 * 5
# Out:
# 15

# %%
3-5
# Out:
# -2

# %%
#standard division
6/2
# Out:
# 3.0

# %%
7/2
# Out:
# 3.5

# %%
# integer division
6 //2
# Out:
# 3

# %%
7 // 2
# Out:
# 3

# %%
#modulus divison

6 % 2
# Out:
# 0

# %%
7 % 2
# Out:
# 1

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
#power operator
2 ** 3
# Out:
# 8

# %%
2 + 3
# Out:
# 5

# %%
2 + 3.0
# Out:
# 5.0

# %%
2.0 + 3.0
# Out:
# 5.0
