# %%
empty_list = []

# %%
top_cities = ['New York City', 'Los Angeles', 'Chicage', 'Houston', 'Phoenix']
print (top_cities)
# Out:
# ['New York City', 'Los Angeles', 'Chicage', 'Houston', 'Phoenix']

# %%
top_cities
# Out:
# ['New York City', 'Los Angeles', 'Chicage', 'Houston', 'Phoenix']

# %%
top_cities[0]
# Out:
# 'New York City'

# %%
top_cities[1]
# Out:
# 'Los Angeles'

# %%
top_cities[4]
# Out:
# 'Phoenix'

# %%
top_cities[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 top_cities[5]
#
# IndexError: list index out of range

# %%
top_cities[-1]
# Out:
# 'Phoenix'

# %%
top_cities[-2]
# Out:
# 'Houston'

# %%
top_cities[-5]
# Out:
# 'New York City'

# %%
top_cities[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 top_cities[-6]
#
# IndexError: list index out of range

# %%
top_cities[0:2]
# Out:
# ['New York City', 'Los Angeles']

# %%
top_cities[2:]
# Out:
# ['Chicage', 'Houston', 'Phoenix']

# %%
top_cities[:3]
# Out:
# ['New York City', 'Los Angeles', 'Chicage']

# %%
top_cities[:]
# Out:
# ['New York City', 'Los Angeles', 'Chicage', 'Houston', 'Phoenix']

# %%
top_cities
# Out:
# ['New York City', 'Los Angeles', 'Chicage', 'Houston', 'Phoenix']

# %%
top_cities[10:15]
# Out:
# []

# %%
top_city = 'New York City'
top_cities[]
top_cities['New York City', 'Los Angeles', 'Chicago', 'Houston', 'Pheonix']
top_cities[0]
top_cities[=5]
