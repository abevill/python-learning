# %%
&
|
~
^
<<
>>

# %%
first_bit = 1 
second_bit = 1

print(first_bit & second_bit)
# Out:
# 1

# %%
first_bit = 0
second_bit = 0

print(first_bit | second_bit)
# Out:
# 0

# %%
first_bit = 0
second_bit = 0

print(first_bit ^ second_bit)
# Out:
# 0

# %%
print (~0)
# Out:
# -1

# %%
12 << 1
# Out:
# 24

# %%
12 << 2
# Out:
# 48

# %%
12 << 3
# Out:
# 96

# %%
12 >> 1
# Out:
# 6

# %%
12 >> 2
# Out:
# 3
